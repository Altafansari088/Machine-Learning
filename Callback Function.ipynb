# %% [markdown]
# Q1. Install and load the latest versions of TensorFlow and Keras. Print their versions.
#
# You can install TensorFlow and Keras using pip or conda. For example:

# %%
pip install tensorflow
pip install keras

# %%
import tensorflow as tf
import keras

print("TensorFlow version:", tf.__version__)
print("Keras version:", keras.__version__)

# %% [markdown]
# Q2. Load the Wine Quality dataset and explore its dimensions.
#
# Download the Wine Quality dataset from the provided link.
#
# Load the dataset into a pandas DataFrame and explore its dimensions using the shape attribute.
#
# Q3. Check for null values, identify categorical variables, and encode them.
#
# Use the isnull() function to check for null values in the DataFrame.
#
# Identify categorical variables by examining the data types or unique values in the columns.
#
# Encode categorical variables using techniques like one-hot encoding or label encoding.
#
# Q4. Separate the features and target variables from the dataframe.
#
# Identify the target variable column in the DataFrame.
#
# Separate the features (input variables) and the target variable into separate variables.
#
# Q5. Perform a train-test split and divide the data into training, validation, and test datasets.
#
# Use the train_test_split function from scikit-learn to split the data into training and test sets.
#
# Optionally, you can further split the training set into training and validation sets.
#
# Q6. Perform scaling on the dataset.
#
# Use appropriate scaling techniques like StandardScaler or MinMaxScaler to scale the numerical features in the dataset.
#
# Q7. Create at least 2 hidden layers and an output layer for the binary categorical variables.
#
# Use the Dense class from Keras to create hidden layers and an output layer.
#
# Specify the number of neurons and activation functions for each layer.
#
# Q8. Create a Sequential model and add all the layers to it.
#
# Create a Sequential model using the Sequential class from Keras.
#
# Add the created layers to the model using the add method.
#
# Q9. Implement a TensorBoard callback to visualize and monitor the model's training process.
#
# Import the TensorBoard callback from Keras.
#
# Create an instance of the callback and specify the log directory.
#
# Q10. Use Early Stopping to prevent overfitting by monitoring a chosen metric and stopping the training if no improvement is observed.
#
# Import the EarlyStopping callback from Keras.
#
# Create an instance of the callback and specify the monitored metric and the patience value.
#
# Q11. Implement a ModelCheckpoint callback to save the best model based on a chosen metric during training.
#
# Import the ModelCheckpoint callback from Keras.
#
# Create an instance of the callback and specify the file path to save the best model.
#
# Q12. Print the model summary.
#
# Use the summary method of the model to print the summary.
#
# Q13. Use binary cross-entropy as the loss function, Adam optimizer, and include the metric ['accuracy'].
#
# Compile the model using the compile method of the model.
#
# Specify the loss function, optimizer, and metrics.
#
# Q14. Compile the model with the specified loss function, optimizer, and metrics.
#
# Use the compile method of the model to compile it with the specified parameters.
#
# Q15. Fit the model to the data, incorporating the TensorBoard, Early Stopping, and ModelCheckpoint callbacks.
#
# Use the fit method of the model to train it on the training data.
#
# Specify the validation data and include the callbacks.
#
# Q16. Get the model's parameters.
#
# Use the get_weights method of the model to get the parameters.
#
# Q17. Store the model's training history as a Pandas DataFrame.
#
# Access the history attribute of the fitted model.
#
# Convert the history dictionary to a DataFrame using the pd.DataFrame constructor.
#
# Q18. Plot the model's training history.
#
# Use the plot method of the DataFrame or matplotlib to plot the training history.
#
# Q19. Evaluate the model's performance using the test data.
#
# Use the evaluate method of the model to evaluate its performance on the test data.
