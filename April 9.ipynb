# %% [markdown]
# Q1. What is Bayes' theorem?
#
# Bayes' theorem is a fundamental concept in probability theory and statistics. It describes how to update the probability of a hypothesis based on new evidence. It is named after the Reverend Thomas Bayes, who introduced the theorem in the 18th century.
#
# Q2. What is the formula for Bayes' theorem?
#
# The formula for Bayes' theorem is:
#
# P(A|B) = (P(B|A) * P(A)) / P(B)
#
# Where:
# P(A|B) is the probability of event A given event B.
#
# P(B|A) is the probability of event B given event A.
#
# P(A) is the prior probability of event A.
#
# P(B) is the prior probability of event B.
#
# Q3. How is Bayes' theorem used in practice?
#
# Bayes' theorem is used in various fields, including statistics, machine learning, and data science. It is commonly used in Bayesian inference, which is a method for updating probabilities based on new evidence. It is also used in spam filtering, medical diagnosis, and many other applications where probabilities need to be updated based on new information.
#
# Q4. What is the relationship between Bayes' theorem and conditional probability?
#
# Bayes' theorem relates conditional probabilities. It provides a way to calculate the probability of an event A given that event B has occurred, based on the conditional probability of event B given event A and the prior probabilities of events A and B.
#
# Q5. How do you choose which type of Naive Bayes classifier to use for any given problem?
#
# The choice of the type of Naive Bayes classifier depends on the nature of the data and the assumptions made about the independence of the features. The three main types of Naive Bayes classifiers are:
#
# Gaussian Naive Bayes: Assumes that the features follow a Gaussian distribution.
#
# Multinomial Naive Bayes: Suitable for discrete features, such as word counts.
#
# Bernoulli Naive Bayes: Suitable for binary features, where each feature is either present or absent.
#
# The choice of the Naive Bayes classifier depends on the specific problem and the characteristics of the data.
#
# Q6. Assuming equal prior probabilities for each class, which class would Naive Bayes predict the new instance to belong to?
#
# To predict the class of a new instance using Naive Bayes, we calculate the posterior probability of each class given the features of the new instance and choose the class with the highest probability.
#
# In this case, we have two classes, A and B, and the features X1 and X2. The frequency table provided shows the frequency of each feature value for each class. To calculate the posterior probabilities, we need to calculate the likelihoods of the features given each class and multiply them by the prior probabilities of each class.
# Using the given frequency table, we can calculate the likelihoods as follows:
#
# P(X1=3 | A) = 4/10
#
# P(X2=4 | A) = 3/10
#
# P(X1=3 | B) = 1/10
#
# P(X2=4 | B) = 3/10
#
# Since the prior probabilities are assumed to be equal for each class, we can ignore them in this case.
#
# To calculate the posterior probabilities, we multiply the likelihoods:
#
# P(A | X1=3, X2=4) = P(X1=3 | A) * P(X2=4 | A) = (4/10) * (3/10) = 12/100 = 0.12
#
# P(B | X1=3, X2=4) = P(X1=3 | B) * P(X2=4 | B) = (1/10) * (3/10) = 3/100 = 0.03
#
# Since P(A | X1=3, X2=4) > P(B | X1=3, X2=4), the Naive Bayes classifier would predict the new instance to belong to class A.
